# %%
import pandas as pd
from ift6758.visualizations import heatmap

# %%
df = pd.read_csv("../ift6758/data/preprocessed_data/preprocessed_game_data.csv")
df['is_goal'] = df['type'] == 'goal'

# %%
df
# Out:
#            game id    season        date venue_location home_team  \
# 0       2017020001  20172018  2017-10-04       Winnipeg      Jets
# 1       2017020001  20172018  2017-10-04       Winnipeg      Jets
# 2       2017020001  20172018  2017-10-04       Winnipeg      Jets
# 3       2017020001  20172018  2017-10-04       Winnipeg      Jets
# 4       2017020001  20172018  2017-10-04       Winnipeg      Jets
# ...            ...       ...         ...            ...       ...
# 529388  2023021312  20232024  2024-04-18    Los Angeles     Kings
# 529389  2023021312  20232024  2024-04-18    Los Angeles     Kings
# 529390  2023021312  20232024  2024-04-18    Los Angeles     Kings
# 529391  2023021312  20232024  2024-04-18    Los Angeles     Kings
# 529392  2023021312  20232024  2024-04-18    Los Angeles     Kings
#
#           away_team  event_id  period timeInPeriod timeRemaining  ...  \
# 0       Maple Leafs        54       1        00:38         19:22  ...
# 1       Maple Leafs        55       1        00:49         19:11  ...
# 2       Maple Leafs        58       1        01:03         18:57  ...
# 3       Maple Leafs        62       1        01:46         18:14  ...
# 4       Maple Leafs        68       1        03:42         16:18  ...
# ...             ...       ...     ...          ...           ...  ...
# 529388   Blackhawks       935       3        09:00         11:00  ...
# 529389   Blackhawks       971       3        12:41         07:19  ...
# 529390   Blackhawks      1024       3        17:28         02:32  ...
# 529391   Blackhawks      1039       3        18:39         01:21  ...
# 529392   Blackhawks      1056       4        00:06         04:54  ...
#
#        shooting_player_id  shooting_player_name  goalie_id        goalie_name  \
# 0                 8477504        Josh Morrissey  8475883.0  Frederik Andersen
# 1                 8473574        Shawn Matthias  8475883.0  Frederik Andersen
# 2                 8473412          Bryan Little  8475883.0  Frederik Andersen
# 3                 8470611             Eric Fehr  8473461.0        Steve Mason
# 4                 8479339          Patrik Laine  8475883.0  Frederik Andersen
# ...                   ...                   ...        ...                ...
# 529388            8476479       Phillip Danault  8482821.0    Arvid Soderblom
# 529389            8482124       Quinton Byfield  8482821.0    Arvid Soderblom
# 529390            8478882    Vladislav Gavrikov  8482821.0    Arvid Soderblom
# 529391            8478042      Viktor Arvidsson  8482821.0    Arvid Soderblom
# 529392            8477960          Adrian Kempe  8482821.0    Arvid Soderblom
#
#         x_coord y_coord  owner_team shot_type  zone_code  is_goal
# 0         -36.0   -28.0          52     wrist          O    False
# 1         -75.0     1.0          52     wrist          O    False
# 2         -73.0    10.0          52  backhand          O    False
# 3          80.0    -3.0          10     wrist          O    False
# 4         -44.0   -21.0          52      snap          O    False
# ...         ...     ...         ...       ...        ...      ...
# 529388    -73.0   -27.0          26     wrist          O    False
# 529389    -74.0   -21.0          26     wrist          O    False
# 529390    -27.0   -27.0          26      slap          O    False
# 529391    -74.0     8.0          26     wrist          O     True
# 529392     64.0   -21.0          26      snap          O     True
#
# [529393 rows x 24 columns]

# %%
df_2020 = df[df['season'] == 20202021]
x_coords = df_2020['x_coord'].to_list()
x_coords_int = [int(x) for x in x_coords]
y_coords = df_2020['y_coord'].to_list()
y_coords_int = [int(y) for y in y_coords]
heatmap.plot_coords_on_heatmap(x_coords_int, y_coords_int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 6
#       4 y_coords = df_2020['y_coord'].to_list()
#       5 y_coords_int = [int(y) for y in y_coords]
# ----> 6 heatmap.plot_coords_on_heatmap(x_coords_int, y_coords_int)
#
# File ~\Documents\agrosante udem\cours\data science\nhl project\IFT-6758-project\ift6758\visualizations\heatmap.py:27, in plot_coords_on_heatmap(x_s, y_s, image)
#      25 for x, y in zip(x_s, y_s):
#      26     image_coords_x, image_coords_y = get_coord(x, y)
# ---> 27     x.append(image_coords_x)
#      28     y.append(image_coords_y)
#      29 hm, xedges, yedges = np.histogram2d(x, y, bins=(100, 100))
#
# AttributeError: 'int' object has no attribute 'append'
