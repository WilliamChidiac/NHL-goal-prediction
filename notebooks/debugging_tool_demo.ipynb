# %%
from ift6758.visualizations import debugging_tool

# %%
debugging_tool.display_season_data("2022")
# Out:
# IntSlider(value=808, description='Game ID:', max=1353, min=1)
# id 2022020808
# date 2023-02-06
# Venue Location:  Sunrise
# Home Team:  Panthers
# Away Team: Lightning
# IntSlider(value=2, description='Event ID:', max=314)
# 9
# hit
# -19
# -38
