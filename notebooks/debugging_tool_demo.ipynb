# %%
import sys
sys.path.append('..')
from ift6758.visualizations import debugging_tool

# %% [markdown]
# # Explanation for blog post
# For a given season, the tool allows the user to scroll any game. In each game, it is possible to scroll through all the events.
# If an event has an x and y coordinates (if it's a hit or a shot-on-goal for example), they will be displayed on the ice rink.
# Game data will be retrieved from cache if present, or from the api.
#
# test game ids: https://www.nhl.com/gamecenter/bos-vs-fla/2023/04/17/2022030111/playbyplay

# %%
# TODO add parameter to disable save file on disk
debugging_tool.display_regular_season("2022")
# Out:
# IntSlider(value=1302, description='Game ID:', max=1312, min=1)
# id 2022021302
# date 2023-04-13
# Venue Location:  Buffalo
# Home Team:  Sabres
# Away Team: Senators
# IntSlider(value=0, description='Event no:', max=314)

# %%
debugging_tool.display_playoff_season("2022")
# Out:
# Dropdown(description='Game id:', index=3, options=('2022_03_0-1-1-1', '2022_03_0-1-1-2', '2022_03_0-1-1-3', '2…
# id 2022030114
# date 2023-04-23
# Venue Location:  Sunrise
# Home Team:  Panthers
# Away Team: Bruins
# IntSlider(value=357, description='Event no:', max=360)
# event id:  1001
# event description:  faceoff
# x:  0 y:  0
