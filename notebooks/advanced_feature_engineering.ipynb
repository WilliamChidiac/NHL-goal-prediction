# %%
from sys import path
path.append('..')
from ift6758.features.preprocess_II import PreprocessII  as pp2
from ift6758.features.feature_engineering_II import  FeatureEngineeringII as fe2
import pandas as pd

# %%
df = pp2.get_games_df(list(range(2016, 2020)))
df
# Out:
# Using cached data for game id:  2016020001
# using cached data for game id:  2016020001.json
# using cached data for game id:  2016020001.json
# printing game : Game 2016020001 on 2016-10-12 between (9, 'OTT', 5) and (10, 'TOR', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020002
# using cached data for game id:  2016020002.json
# using cached data for game id:  2016020002.json
# printing game : Game 2016020002 on 2016-10-12 between (16, 'CHI', 2) and (19, 'STL', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020003
# using cached data for game id:  2016020003.json
# using cached data for game id:  2016020003.json
# printing game : Game 2016020003 on 2016-10-12 between (22, 'EDM', 7) and (20, 'CGY', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020004
# using cached data for game id:  2016020004.json
# using cached data for game id:  2016020004.json
# printing game : Game 2016020004 on 2016-10-12 between (28, 'SJS', 2) and (26, 'LAK', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020005
# using cached data for game id:  2016020005.json
# using cached data for game id:  2016020005.json
# printing game : Game 2016020005 on 2016-10-13 between (7, 'BUF', 1) and (8, 'MTL', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020006
# using cached data for game id:  2016020006.json
# using cached data for game id:  2016020006.json
# printing game : Game 2016020006 on 2016-10-13 between (3, 'NYR', 5) and (2, 'NYI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020007
# using cached data for game id:  2016020007.json
# using cached data for game id:  2016020007.json
# printing game : Game 2016020007 on 2016-10-13 between (5, 'PIT', 3) and (15, 'WSH', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020008
# using cached data for game id:  2016020008.json
# using cached data for game id:  2016020008.json
# printing game : Game 2016020008 on 2016-10-13 between (29, 'CBJ', 3) and (6, 'BOS', 6)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020009
# using cached data for game id:  2016020009.json
# using cached data for game id:  2016020009.json
# printing game : Game 2016020009 on 2016-10-13 between (14, 'TBL', 6) and (17, 'DET', 4)
# rebound
# Using cached data for game id:  2016020010
# using cached data for game id:  2016020010.json
# using cached data for game id:  2016020010.json
# printing game : Game 2016020010 on 2016-10-13 between (13, 'FLA', 2) and (1, 'NJD', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020011
# using cached data for game id:  2016020011.json
# using cached data for game id:  2016020011.json
# printing game : Game 2016020011 on 2016-10-13 between (19, 'STL', 3) and (30, 'MIN', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020012
# using cached data for game id:  2016020012.json
# using cached data for game id:  2016020012.json
# printing game : Game 2016020012 on 2016-10-13 between (52, 'WPG', 5) and (12, 'CAR', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020013
# using cached data for game id:  2016020013.json
# using cached data for game id:  2016020013.json
# printing game : Game 2016020013 on 2016-10-13 between (25, 'DAL', 4) and (24, 'ANA', 2)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020014
# using cached data for game id:  2016020014.json
# using cached data for game id:  2016020014.json
# printing game : Game 2016020014 on 2016-10-14 between (18, 'NSH', 3) and (16, 'CHI', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020015
# using cached data for game id:  2016020015.json
# using cached data for game id:  2016020015.json
# printing game : Game 2016020015 on 2016-10-14 between (20, 'CGY', 3) and (22, 'EDM', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020016
# using cached data for game id:  2016020016.json
# using cached data for game id:  2016020016.json
# printing game : Game 2016020016 on 2016-10-14 between (26, 'LAK', 2) and (4, 'PHI', 4)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020017
# using cached data for game id:  2016020017.json
# using cached data for game id:  2016020017.json
# printing game : Game 2016020017 on 2016-10-15 between (10, 'TOR', 4) and (6, 'BOS', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020018
# using cached data for game id:  2016020018.json
# using cached data for game id:  2016020018.json
# printing game : Game 2016020018 on 2016-10-15 between (9, 'OTT', 4) and (8, 'MTL', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020019
# using cached data for game id:  2016020019.json
# using cached data for game id:  2016020019.json
# printing game : Game 2016020019 on 2016-10-15 between (14, 'TBL', 3) and (1, 'NJD', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020020
# using cached data for game id:  2016020020.json
# using cached data for game id:  2016020020.json
# printing game : Game 2016020020 on 2016-10-15 between (13, 'FLA', 4) and (17, 'DET', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020021
# using cached data for game id:  2016020021.json
# using cached data for game id:  2016020021.json
# printing game : Game 2016020021 on 2016-10-15 between (5, 'PIT', 3) and (24, 'ANA', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020022
# using cached data for game id:  2016020022.json
# using cached data for game id:  2016020022.json
# printing game : Game 2016020022 on 2016-10-15 between (15, 'WSH', 2) and (2, 'NYI', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020023
# using cached data for game id:  2016020023.json
# using cached data for game id:  2016020023.json
# printing game : Game 2016020023 on 2016-10-15 between (29, 'CBJ', 2) and (28, 'SJS', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020024
# using cached data for game id:  2016020024.json
# using cached data for game id:  2016020024.json
# printing game : Game 2016020024 on 2016-10-15 between (30, 'MIN', 4) and (52, 'WPG', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020025
# using cached data for game id:  2016020025.json
# using cached data for game id:  2016020025.json
# printing game : Game 2016020025 on 2016-10-15 between (19, 'STL', 3) and (3, 'NYR', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020026
# using cached data for game id:  2016020026.json
# using cached data for game id:  2016020026.json
# printing game : Game 2016020026 on 2016-10-15 between (16, 'CHI', 5) and (18, 'NSH', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020027
# using cached data for game id:  2016020027.json
# using cached data for game id:  2016020027.json
# printing game : Game 2016020027 on 2016-10-15 between (21, 'COL', 6) and (25, 'DAL', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020028
# using cached data for game id:  2016020028.json
# using cached data for game id:  2016020028.json
# printing game : Game 2016020028 on 2016-10-15 between (53, 'ARI', 4) and (4, 'PHI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020029
# using cached data for game id:  2016020029.json
# using cached data for game id:  2016020029.json
# printing game : Game 2016020029 on 2016-10-15 between (23, 'VAN', 2) and (20, 'CGY', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020030
# using cached data for game id:  2016020030.json
# using cached data for game id:  2016020030.json
# printing game : Game 2016020030 on 2016-10-16 between (2, 'NYI', 3) and (24, 'ANA', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020031
# using cached data for game id:  2016020031.json
# using cached data for game id:  2016020031.json
# printing game : Game 2016020031 on 2016-10-16 between (22, 'EDM', 2) and (7, 'BUF', 6)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020032
# using cached data for game id:  2016020032.json
# using cached data for game id:  2016020032.json
# printing game : Game 2016020032 on 2016-10-16 between (23, 'VAN', 4) and (12, 'CAR', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020033
# using cached data for game id:  2016020033.json
# using cached data for game id:  2016020033.json
# printing game : Game 2016020033 on 2016-10-17 between (3, 'NYR', 7) and (28, 'SJS', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020034
# using cached data for game id:  2016020034.json
# using cached data for game id:  2016020034.json
# printing game : Game 2016020034 on 2016-10-17 between (5, 'PIT', 3) and (21, 'COL', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020035
# using cached data for game id:  2016020035.json
# using cached data for game id:  2016020035.json
# printing game : Game 2016020035 on 2016-10-17 between (17, 'DET', 5) and (9, 'OTT', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020036
# using cached data for game id:  2016020036.json
# using cached data for game id:  2016020036.json
# printing game : Game 2016020036 on 2016-10-17 between (52, 'WPG', 1) and (6, 'BOS', 4)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020037
# using cached data for game id:  2016020037.json
# using cached data for game id:  2016020037.json
# printing game : Game 2016020037 on 2016-10-18 between (1, 'NJD', 2) and (24, 'ANA', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020038
# using cached data for game id:  2016020038.json
# using cached data for game id:  2016020038.json
# printing game : Game 2016020038 on 2016-10-18 between (2, 'NYI', 2) and (28, 'SJS', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020039
# using cached data for game id:  2016020039.json
# using cached data for game id:  2016020039.json
# printing game : Game 2016020039 on 2016-10-18 between (15, 'WSH', 3) and (21, 'COL', 0)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020040
# using cached data for game id:  2016020040.json
# using cached data for game id:  2016020040.json
# printing game : Game 2016020040 on 2016-10-18 between (8, 'MTL', 4) and (5, 'PIT', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020041
# using cached data for game id:  2016020041.json
# using cached data for game id:  2016020041.json
# printing game : Game 2016020041 on 2016-10-18 between (9, 'OTT', 7) and (53, 'ARI', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020042
# using cached data for game id:  2016020042.json
# using cached data for game id:  2016020042.json
# printing game : Game 2016020042 on 2016-10-18 between (14, 'TBL', 4) and (13, 'FLA', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020043
# using cached data for game id:  2016020043.json
# using cached data for game id:  2016020043.json
# printing game : Game 2016020043 on 2016-10-18 between (18, 'NSH', 1) and (25, 'DAL', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020044
# using cached data for game id:  2016020044.json
# using cached data for game id:  2016020044.json
# printing game : Game 2016020044 on 2016-10-18 between (30, 'MIN', 6) and (26, 'LAK', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020045
# using cached data for game id:  2016020045.json
# using cached data for game id:  2016020045.json
# printing game : Game 2016020045 on 2016-10-18 between (16, 'CHI', 7) and (4, 'PHI', 4)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020046
# using cached data for game id:  2016020046.json
# using cached data for game id:  2016020046.json
# printing game : Game 2016020046 on 2016-10-18 between (20, 'CGY', 4) and (7, 'BUF', 3)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020047
# using cached data for game id:  2016020047.json
# using cached data for game id:  2016020047.json
# printing game : Game 2016020047 on 2016-10-18 between (22, 'EDM', 3) and (12, 'CAR', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020048
# using cached data for game id:  2016020048.json
# using cached data for game id:  2016020048.json
# printing game : Game 2016020048 on 2016-10-18 between (23, 'VAN', 2) and (19, 'STL', 1)
# rebound
# rebound
# Using cached data for game id:  2016020049
# using cached data for game id:  2016020049.json
# using cached data for game id:  2016020049.json
# printing game : Game 2016020049 on 2016-10-19 between (3, 'NYR', 1) and (17, 'DET', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020050
# using cached data for game id:  2016020050.json
# using cached data for game id:  2016020050.json
# printing game : Game 2016020050 on 2016-10-19 between (52, 'WPG', 5) and (10, 'TOR', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020051
# using cached data for game id:  2016020051.json
# using cached data for game id:  2016020051.json
# printing game : Game 2016020051 on 2016-10-20 between (6, 'BOS', 2) and (1, 'NJD', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020052
# using cached data for game id:  2016020052.json
# using cached data for game id:  2016020052.json
# printing game : Game 2016020052 on 2016-10-20 between (4, 'PHI', 2) and (24, 'ANA', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020053
# using cached data for game id:  2016020053.json
# using cached data for game id:  2016020053.json
# printing game : Game 2016020053 on 2016-10-20 between (5, 'PIT', 3) and (28, 'SJS', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020054
# using cached data for game id:  2016020054.json
# using cached data for game id:  2016020054.json
# printing game : Game 2016020054 on 2016-10-20 between (8, 'MTL', 5) and (53, 'ARI', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020055
# using cached data for game id:  2016020055.json
# using cached data for game id:  2016020055.json
# printing game : Game 2016020055 on 2016-10-20 between (14, 'TBL', 0) and (21, 'COL', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020056
# using cached data for game id:  2016020056.json
# using cached data for game id:  2016020056.json
# printing game : Game 2016020056 on 2016-10-20 between (13, 'FLA', 2) and (15, 'WSH', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020057
# using cached data for game id:  2016020057.json
# using cached data for game id:  2016020057.json
# printing game : Game 2016020057 on 2016-10-20 between (30, 'MIN', 3) and (10, 'TOR', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020058
# using cached data for game id:  2016020058.json
# using cached data for game id:  2016020058.json
# printing game : Game 2016020058 on 2016-10-20 between (25, 'DAL', 3) and (26, 'LAK', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020059
# using cached data for game id:  2016020059.json
# using cached data for game id:  2016020059.json
# printing game : Game 2016020059 on 2016-10-20 between (20, 'CGY', 2) and (12, 'CAR', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020060
# using cached data for game id:  2016020060.json
# using cached data for game id:  2016020060.json
# printing game : Game 2016020060 on 2016-10-20 between (22, 'EDM', 3) and (19, 'STL', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020061
# using cached data for game id:  2016020061.json
# using cached data for game id:  2016020061.json
# printing game : Game 2016020061 on 2016-10-20 between (23, 'VAN', 2) and (7, 'BUF', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020062
# using cached data for game id:  2016020062.json
# using cached data for game id:  2016020062.json
# printing game : Game 2016020062 on 2016-10-21 between (2, 'NYI', 3) and (53, 'ARI', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020063
# using cached data for game id:  2016020063.json
# using cached data for game id:  2016020063.json
# printing game : Game 2016020063 on 2016-10-21 between (29, 'CBJ', 3) and (16, 'CHI', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020064
# using cached data for game id:  2016020064.json
# using cached data for game id:  2016020064.json
# printing game : Game 2016020064 on 2016-10-21 between (17, 'DET', 5) and (18, 'NSH', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020065
# using cached data for game id:  2016020065.json
# using cached data for game id:  2016020065.json
# printing game : Game 2016020065 on 2016-10-22 between (6, 'BOS', 2) and (8, 'MTL', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020066
# using cached data for game id:  2016020066.json
# using cached data for game id:  2016020066.json
# printing game : Game 2016020066 on 2016-10-22 between (9, 'OTT', 1) and (14, 'TBL', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020067
# using cached data for game id:  2016020067.json
# using cached data for game id:  2016020067.json
# printing game : Game 2016020067 on 2016-10-22 between (17, 'DET', 3) and (28, 'SJS', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020068
# using cached data for game id:  2016020068.json
# using cached data for game id:  2016020068.json
# printing game : Game 2016020068 on 2016-10-22 between (13, 'FLA', 5) and (21, 'COL', 2)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020069
# using cached data for game id:  2016020069.json
# using cached data for game id:  2016020069.json
# printing game : Game 2016020069 on 2016-10-22 between (1, 'NJD', 2) and (30, 'MIN', 1)
# rebound
# Using cached data for game id:  2016020070
# using cached data for game id:  2016020070.json
# using cached data for game id:  2016020070.json
# printing game : Game 2016020070 on 2016-10-22 between (4, 'PHI', 6) and (12, 'CAR', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020071
# using cached data for game id:  2016020071.json
# using cached data for game id:  2016020071.json
# printing game : Game 2016020071 on 2016-10-22 between (15, 'WSH', 2) and (3, 'NYR', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020072
# using cached data for game id:  2016020072.json
# using cached data for game id:  2016020072.json
# printing game : Game 2016020072 on 2016-10-22 between (16, 'CHI', 5) and (10, 'TOR', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020073
# using cached data for game id:  2016020073.json
# using cached data for game id:  2016020073.json
# printing game : Game 2016020073 on 2016-10-22 between (18, 'NSH', 5) and (5, 'PIT', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020074
# using cached data for game id:  2016020074.json
# using cached data for game id:  2016020074.json
# printing game : Game 2016020074 on 2016-10-22 between (25, 'DAL', 0) and (29, 'CBJ', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020075
# using cached data for game id:  2016020075.json
# using cached data for game id:  2016020075.json
# printing game : Game 2016020075 on 2016-10-22 between (20, 'CGY', 4) and (19, 'STL', 6)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020076
# using cached data for game id:  2016020076.json
# using cached data for game id:  2016020076.json
# printing game : Game 2016020076 on 2016-10-22 between (26, 'LAK', 4) and (23, 'VAN', 3)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020077
# using cached data for game id:  2016020077.json
# using cached data for game id:  2016020077.json
# printing game : Game 2016020077 on 2016-10-23 between (52, 'WPG', 0) and (22, 'EDM', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020078
# using cached data for game id:  2016020078.json
# using cached data for game id:  2016020078.json
# printing game : Game 2016020078 on 2016-10-23 between (2, 'NYI', 6) and (30, 'MIN', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020079
# using cached data for game id:  2016020079.json
# using cached data for game id:  2016020079.json
# printing game : Game 2016020079 on 2016-10-23 between (3, 'NYR', 3) and (53, 'ARI', 2)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020080
# using cached data for game id:  2016020080.json
# using cached data for game id:  2016020080.json
# printing game : Game 2016020080 on 2016-10-23 between (24, 'ANA', 4) and (23, 'VAN', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020081
# using cached data for game id:  2016020081.json
# using cached data for game id:  2016020081.json
# printing game : Game 2016020081 on 2016-10-24 between (8, 'MTL', 3) and (4, 'PHI', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020082
# using cached data for game id:  2016020082.json
# using cached data for game id:  2016020082.json
# printing game : Game 2016020082 on 2016-10-24 between (16, 'CHI', 2) and (20, 'CGY', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020083
# using cached data for game id:  2016020083.json
# using cached data for game id:  2016020083.json
# printing game : Game 2016020083 on 2016-10-25 between (6, 'BOS', 0) and (30, 'MIN', 5)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020084
# using cached data for game id:  2016020084.json
# using cached data for game id:  2016020084.json
# printing game : Game 2016020084 on 2016-10-25 between (1, 'NJD', 5) and (53, 'ARI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020085
# using cached data for game id:  2016020085.json
# using cached data for game id:  2016020085.json
# printing game : Game 2016020085 on 2016-10-25 between (4, 'PHI', 4) and (7, 'BUF', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020086
# using cached data for game id:  2016020086.json
# using cached data for game id:  2016020086.json
# printing game : Game 2016020086 on 2016-10-25 between (5, 'PIT', 3) and (13, 'FLA', 2)
# rebound
# rebound
# Using cached data for game id:  2016020087
# using cached data for game id:  2016020087.json
# using cached data for game id:  2016020087.json
# printing game : Game 2016020087 on 2016-10-25 between (10, 'TOR', 3) and (14, 'TBL', 7)
# rebound
# rebound
# Using cached data for game id:  2016020088
# using cached data for game id:  2016020088.json
# using cached data for game id:  2016020088.json
# printing game : Game 2016020088 on 2016-10-25 between (17, 'DET', 4) and (12, 'CAR', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020089
# using cached data for game id:  2016020089.json
# using cached data for game id:  2016020089.json
# printing game : Game 2016020089 on 2016-10-25 between (19, 'STL', 1) and (20, 'CGY', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020090
# using cached data for game id:  2016020090.json
# using cached data for game id:  2016020090.json
# printing game : Game 2016020090 on 2016-10-25 between (25, 'DAL', 3) and (52, 'WPG', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020091
# using cached data for game id:  2016020091.json
# using cached data for game id:  2016020091.json
# printing game : Game 2016020091 on 2016-10-25 between (23, 'VAN', 0) and (9, 'OTT', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020092
# using cached data for game id:  2016020092.json
# using cached data for game id:  2016020092.json
# printing game : Game 2016020092 on 2016-10-25 between (26, 'LAK', 3) and (29, 'CBJ', 2)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020093
# using cached data for game id:  2016020093.json
# using cached data for game id:  2016020093.json
# printing game : Game 2016020093 on 2016-10-25 between (28, 'SJS', 2) and (24, 'ANA', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020094
# using cached data for game id:  2016020094.json
# using cached data for game id:  2016020094.json
# printing game : Game 2016020094 on 2016-10-26 between (2, 'NYI', 2) and (8, 'MTL', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020095
# using cached data for game id:  2016020095.json
# using cached data for game id:  2016020095.json
# printing game : Game 2016020095 on 2016-10-26 between (3, 'NYR', 5) and (6, 'BOS', 2)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020096
# using cached data for game id:  2016020096.json
# using cached data for game id:  2016020096.json
# printing game : Game 2016020096 on 2016-10-26 between (22, 'EDM', 4) and (15, 'WSH', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020097
# using cached data for game id:  2016020097.json
# using cached data for game id:  2016020097.json
# printing game : Game 2016020097 on 2016-10-26 between (24, 'ANA', 6) and (18, 'NSH', 1)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020098
# using cached data for game id:  2016020098.json
# using cached data for game id:  2016020098.json
# printing game : Game 2016020098 on 2016-10-27 between (7, 'BUF', 0) and (30, 'MIN', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020099
# using cached data for game id:  2016020099.json
# using cached data for game id:  2016020099.json
# printing game : Game 2016020099 on 2016-10-27 between (4, 'PHI', 4) and (53, 'ARI', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020100
# using cached data for game id:  2016020100.json
# using cached data for game id:  2016020100.json
# printing game : Game 2016020100 on 2016-10-27 between (5, 'PIT', 4) and (2, 'NYI', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020101
# using cached data for game id:  2016020101.json
# using cached data for game id:  2016020101.json
# printing game : Game 2016020101 on 2016-10-27 between (10, 'TOR', 3) and (13, 'FLA', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020102
# using cached data for game id:  2016020102.json
# using cached data for game id:  2016020102.json
# printing game : Game 2016020102 on 2016-10-27 between (8, 'MTL', 3) and (14, 'TBL', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020103
# using cached data for game id:  2016020103.json
# using cached data for game id:  2016020103.json
# printing game : Game 2016020103 on 2016-10-27 between (19, 'STL', 1) and (17, 'DET', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020104
# using cached data for game id:  2016020104.json
# using cached data for game id:  2016020104.json
# printing game : Game 2016020104 on 2016-10-27 between (52, 'WPG', 4) and (25, 'DAL', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020105
# using cached data for game id:  2016020105.json
# using cached data for game id:  2016020105.json
# printing game : Game 2016020105 on 2016-10-27 between (26, 'LAK', 3) and (18, 'NSH', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020106
# using cached data for game id:  2016020106.json
# using cached data for game id:  2016020106.json
# printing game : Game 2016020106 on 2016-10-27 between (28, 'SJS', 3) and (29, 'CBJ', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020107
# using cached data for game id:  2016020107.json
# using cached data for game id:  2016020107.json
# printing game : Game 2016020107 on 2016-10-28 between (1, 'NJD', 2) and (16, 'CHI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020108
# using cached data for game id:  2016020108.json
# using cached data for game id:  2016020108.json
# printing game : Game 2016020108 on 2016-10-28 between (12, 'CAR', 3) and (3, 'NYR', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020109
# using cached data for game id:  2016020109.json
# using cached data for game id:  2016020109.json
# printing game : Game 2016020109 on 2016-10-28 between (21, 'COL', 0) and (52, 'WPG', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020110
# using cached data for game id:  2016020110.json
# using cached data for game id:  2016020110.json
# printing game : Game 2016020110 on 2016-10-28 between (20, 'CGY', 5) and (9, 'OTT', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020111
# using cached data for game id:  2016020111.json
# using cached data for game id:  2016020111.json
# printing game : Game 2016020111 on 2016-10-28 between (23, 'VAN', 0) and (22, 'EDM', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020112
# using cached data for game id:  2016020112.json
# using cached data for game id:  2016020112.json
# printing game : Game 2016020112 on 2016-10-28 between (24, 'ANA', 0) and (29, 'CBJ', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020113
# using cached data for game id:  2016020113.json
# using cached data for game id:  2016020113.json
# printing game : Game 2016020113 on 2016-10-29 between (7, 'BUF', 3) and (13, 'FLA', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020114
# using cached data for game id:  2016020114.json
# using cached data for game id:  2016020114.json
# printing game : Game 2016020114 on 2016-10-29 between (8, 'MTL', 2) and (10, 'TOR', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020115
# using cached data for game id:  2016020115.json
# using cached data for game id:  2016020115.json
# printing game : Game 2016020115 on 2016-10-29 between (17, 'DET', 0) and (6, 'BOS', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020116
# using cached data for game id:  2016020116.json
# using cached data for game id:  2016020116.json
# printing game : Game 2016020116 on 2016-10-29 between (1, 'NJD', 3) and (14, 'TBL', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020117
# using cached data for game id:  2016020117.json
# using cached data for game id:  2016020117.json
# printing game : Game 2016020117 on 2016-10-29 between (4, 'PHI', 4) and (5, 'PIT', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020118
# using cached data for game id:  2016020118.json
# using cached data for game id:  2016020118.json
# printing game : Game 2016020118 on 2016-10-29 between (19, 'STL', 1) and (26, 'LAK', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020119
# using cached data for game id:  2016020119.json
# using cached data for game id:  2016020119.json
# printing game : Game 2016020119 on 2016-10-29 between (30, 'MIN', 4) and (25, 'DAL', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020120
# using cached data for game id:  2016020120.json
# using cached data for game id:  2016020120.json
# printing game : Game 2016020120 on 2016-10-29 between (53, 'ARI', 2) and (21, 'COL', 3)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020121
# using cached data for game id:  2016020121.json
# using cached data for game id:  2016020121.json
# printing game : Game 2016020121 on 2016-10-29 between (23, 'VAN', 2) and (15, 'WSH', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020122
# using cached data for game id:  2016020122.json
# using cached data for game id:  2016020122.json
# printing game : Game 2016020122 on 2016-10-29 between (28, 'SJS', 4) and (18, 'NSH', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020123
# using cached data for game id:  2016020123.json
# using cached data for game id:  2016020123.json
# printing game : Game 2016020123 on 2016-10-30 between (52, 'WPG', 1) and (7, 'BUF', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020124
# using cached data for game id:  2016020124.json
# using cached data for game id:  2016020124.json
# printing game : Game 2016020124 on 2016-10-30 between (17, 'DET', 2) and (13, 'FLA', 5)
# rebound
# rebound
# Using cached data for game id:  2016020125
# using cached data for game id:  2016020125.json
# using cached data for game id:  2016020125.json
# printing game : Game 2016020125 on 2016-10-30 between (12, 'CAR', 3) and (4, 'PHI', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020126
# using cached data for game id:  2016020126.json
# using cached data for game id:  2016020126.json
# printing game : Game 2016020126 on 2016-10-30 between (2, 'NYI', 5) and (10, 'TOR', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020127
# using cached data for game id:  2016020127.json
# using cached data for game id:  2016020127.json
# printing game : Game 2016020127 on 2016-10-30 between (3, 'NYR', 6) and (14, 'TBL', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020128
# using cached data for game id:  2016020128.json
# using cached data for game id:  2016020128.json
# printing game : Game 2016020128 on 2016-10-30 between (16, 'CHI', 3) and (26, 'LAK', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020129
# using cached data for game id:  2016020129.json
# using cached data for game id:  2016020129.json
# printing game : Game 2016020129 on 2016-10-30 between (22, 'EDM', 0) and (9, 'OTT', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020130
# using cached data for game id:  2016020130.json
# using cached data for game id:  2016020130.json
# printing game : Game 2016020130 on 2016-10-30 between (20, 'CGY', 1) and (15, 'WSH', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020131
# using cached data for game id:  2016020131.json
# using cached data for game id:  2016020131.json
# printing game : Game 2016020131 on 2016-11-01 between (2, 'NYI', 1) and (14, 'TBL', 6)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020132
# using cached data for game id:  2016020132.json
# using cached data for game id:  2016020132.json
# printing game : Game 2016020132 on 2016-11-01 between (3, 'NYR', 5) and (19, 'STL', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020133
# using cached data for game id:  2016020133.json
# using cached data for game id:  2016020133.json
# printing game : Game 2016020133 on 2016-11-01 between (29, 'CBJ', 3) and (25, 'DAL', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020134
# using cached data for game id:  2016020134.json
# using cached data for game id:  2016020134.json
# printing game : Game 2016020134 on 2016-11-01 between (10, 'TOR', 3) and (22, 'EDM', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020135
# using cached data for game id:  2016020135.json
# using cached data for game id:  2016020135.json
# printing game : Game 2016020135 on 2016-11-01 between (9, 'OTT', 2) and (12, 'CAR', 1)
# rebound
# rebound
# Using cached data for game id:  2016020136
# using cached data for game id:  2016020136.json
# using cached data for game id:  2016020136.json
# printing game : Game 2016020136 on 2016-11-01 between (13, 'FLA', 1) and (6, 'BOS', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020137
# using cached data for game id:  2016020137.json
# using cached data for game id:  2016020137.json
# printing game : Game 2016020137 on 2016-11-01 between (30, 'MIN', 1) and (7, 'BUF', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020138
# using cached data for game id:  2016020138.json
# using cached data for game id:  2016020138.json
# printing game : Game 2016020138 on 2016-11-01 between (52, 'WPG', 2) and (15, 'WSH', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020139
# using cached data for game id:  2016020139.json
# using cached data for game id:  2016020139.json
# printing game : Game 2016020139 on 2016-11-01 between (16, 'CHI', 5) and (20, 'CGY', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020140
# using cached data for game id:  2016020140.json
# using cached data for game id:  2016020140.json
# printing game : Game 2016020140 on 2016-11-01 between (21, 'COL', 1) and (18, 'NSH', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020141
# using cached data for game id:  2016020141.json
# using cached data for game id:  2016020141.json
# printing game : Game 2016020141 on 2016-11-01 between (53, 'ARI', 3) and (28, 'SJS', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020142
# using cached data for game id:  2016020142.json
# using cached data for game id:  2016020142.json
# printing game : Game 2016020142 on 2016-11-01 between (26, 'LAK', 0) and (24, 'ANA', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020143
# using cached data for game id:  2016020143.json
# using cached data for game id:  2016020143.json
# printing game : Game 2016020143 on 2016-11-02 between (8, 'MTL', 3) and (23, 'VAN', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020144
# using cached data for game id:  2016020144.json
# using cached data for game id:  2016020144.json
# printing game : Game 2016020144 on 2016-11-02 between (4, 'PHI', 4) and (17, 'DET', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020145
# using cached data for game id:  2016020145.json
# using cached data for game id:  2016020145.json
# printing game : Game 2016020145 on 2016-11-02 between (24, 'ANA', 1) and (5, 'PIT', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020146
# using cached data for game id:  2016020146.json
# using cached data for game id:  2016020146.json
# printing game : Game 2016020146 on 2016-11-03 between (7, 'BUF', 1) and (10, 'TOR', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020147
# using cached data for game id:  2016020147.json
# using cached data for game id:  2016020147.json
# printing game : Game 2016020147 on 2016-11-03 between (2, 'NYI', 2) and (4, 'PHI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020148
# using cached data for game id:  2016020148.json
# using cached data for game id:  2016020148.json
# printing game : Game 2016020148 on 2016-11-03 between (3, 'NYR', 5) and (22, 'EDM', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020149
# using cached data for game id:  2016020149.json
# using cached data for game id:  2016020149.json
# printing game : Game 2016020149 on 2016-11-03 between (15, 'WSH', 4) and (52, 'WPG', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020150
# using cached data for game id:  2016020150.json
# using cached data for game id:  2016020150.json
# printing game : Game 2016020150 on 2016-11-03 between (9, 'OTT', 1) and (23, 'VAN', 0)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020151
# using cached data for game id:  2016020151.json
# using cached data for game id:  2016020151.json
# printing game : Game 2016020151 on 2016-11-03 between (14, 'TBL', 3) and (6, 'BOS', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020152
# using cached data for game id:  2016020152.json
# using cached data for game id:  2016020152.json
# printing game : Game 2016020152 on 2016-11-03 between (13, 'FLA', 4) and (1, 'NJD', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020153
# using cached data for game id:  2016020153.json
# using cached data for game id:  2016020153.json
# printing game : Game 2016020153 on 2016-11-03 between (16, 'CHI', 4) and (21, 'COL', 0)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020154
# using cached data for game id:  2016020154.json
# using cached data for game id:  2016020154.json
# printing game : Game 2016020154 on 2016-11-03 between (25, 'DAL', 6) and (19, 'STL', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020155
# using cached data for game id:  2016020155.json
# using cached data for game id:  2016020155.json
# printing game : Game 2016020155 on 2016-11-03 between (53, 'ARI', 3) and (18, 'NSH', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020156
# using cached data for game id:  2016020156.json
# using cached data for game id:  2016020156.json
# printing game : Game 2016020156 on 2016-11-03 between (26, 'LAK', 3) and (5, 'PIT', 2)
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020157
# using cached data for game id:  2016020157.json
# using cached data for game id:  2016020157.json
# printing game : Game 2016020157 on 2016-11-03 between (28, 'SJS', 2) and (20, 'CGY', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020158
# using cached data for game id:  2016020158.json
# using cached data for game id:  2016020158.json
# printing game : Game 2016020158 on 2016-11-04 between (29, 'CBJ', 10) and (8, 'MTL', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020159
# using cached data for game id:  2016020159.json
# using cached data for game id:  2016020159.json
# printing game : Game 2016020159 on 2016-11-04 between (17, 'DET', 3) and (52, 'WPG', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020160
# using cached data for game id:  2016020160.json
# using cached data for game id:  2016020160.json
# printing game : Game 2016020160 on 2016-11-04 between (24, 'ANA', 5) and (53, 'ARI', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020161
# using cached data for game id:  2016020161.json
# using cached data for game id:  2016020161.json
# printing game : Game 2016020161 on 2016-11-05 between (21, 'COL', 1) and (30, 'MIN', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020162
# using cached data for game id:  2016020162.json
# using cached data for game id:  2016020162.json
# printing game : Game 2016020162 on 2016-11-05 between (6, 'BOS', 2) and (3, 'NYR', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020163
# using cached data for game id:  2016020163.json
# using cached data for game id:  2016020163.json
# printing game : Game 2016020163 on 2016-11-05 between (10, 'TOR', 6) and (23, 'VAN', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020164
# using cached data for game id:  2016020164.json
# using cached data for game id:  2016020164.json
# printing game : Game 2016020164 on 2016-11-05 between (8, 'MTL', 5) and (4, 'PHI', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020165
# using cached data for game id:  2016020165.json
# using cached data for game id:  2016020165.json
# printing game : Game 2016020165 on 2016-11-05 between (9, 'OTT', 1) and (7, 'BUF', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# ...
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020276
# using cached data for game id:  2016020276.json
# using cached data for game id:  2016020276.json
# printing game : Game 2016020276 on 2016-11-21 between (7, 'BUF', 4) and (20, 'CGY', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020277
# using cached data for game id:  2016020277.json
# using cached data for game id:  2016020277.json
# printing game : Game 2016020277 on 2016-11-21 between (5, 'PIT', 2) and (3, 'NYR', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020278
# using cached data for game id:  2016020278.json
# using cached data for game id:  2016020278.json
# printing game : Game 2016020278 on 2016-11-21 between (29, 'CBJ', 2) and (21, 'COL', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020279
# using cached data for game id:  2016020279.json
# using cached data for game id:  2016020279.json
# printing game : Game 2016020279 on 2016-11-21 between (18, 'NSH', 3) and (14, 'TBL', 1)
# rebound
# Using cached data for game id:  2016020280
# using cached data for game id:  2016020280.json
# using cached data for game id:  2016020280.json
# printing game : Game 2016020280 on 2016-11-21 between (25, 'DAL', 3) and (30, 'MIN', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020281
# using cached data for game id:  2016020281.json
# using cached data for game id:  2016020281.json
# printing game : Game 2016020281 on 2016-11-21 between (22, 'EDM', 5) and (16, 'CHI', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020282
# using cached data for game id:  2016020282.json
# using cached data for game id:  2016020282.json
# printing game : Game 2016020282 on 2016-11-21 between (28, 'SJS', 4) and (1, 'NJD', 0)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020283
# using cached data for game id:  2016020283.json
# using cached data for game id:  2016020283.json
# printing game : Game 2016020283 on 2016-11-22 between (6, 'BOS', 2) and (19, 'STL', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020284
# using cached data for game id:  2016020284.json
# using cached data for game id:  2016020284.json
# printing game : Game 2016020284 on 2016-11-22 between (10, 'TOR', 1) and (12, 'CAR', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020285
# using cached data for game id:  2016020285.json
# using cached data for game id:  2016020285.json
# printing game : Game 2016020285 on 2016-11-22 between (8, 'MTL', 3) and (9, 'OTT', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020286
# using cached data for game id:  2016020286.json
# using cached data for game id:  2016020286.json
# printing game : Game 2016020286 on 2016-11-22 between (13, 'FLA', 1) and (4, 'PHI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020287
# using cached data for game id:  2016020287.json
# using cached data for game id:  2016020287.json
# printing game : Game 2016020287 on 2016-11-22 between (24, 'ANA', 2) and (2, 'NYI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020288
# using cached data for game id:  2016020288.json
# using cached data for game id:  2016020288.json
# printing game : Game 2016020288 on 2016-11-23 between (7, 'BUF', 1) and (17, 'DET', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020289
# using cached data for game id:  2016020289.json
# using cached data for game id:  2016020289.json
# printing game : Game 2016020289 on 2016-11-23 between (1, 'NJD', 5) and (10, 'TOR', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020290
# using cached data for game id:  2016020290.json
# using cached data for game id:  2016020290.json
# printing game : Game 2016020290 on 2016-11-23 between (3, 'NYR', 1) and (5, 'PIT', 6)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020291
# using cached data for game id:  2016020291.json
# using cached data for game id:  2016020291.json
# printing game : Game 2016020291 on 2016-11-23 between (15, 'WSH', 4) and (19, 'STL', 3)
# rebound
# rebound
# Using cached data for game id:  2016020292
# using cached data for game id:  2016020292.json
# using cached data for game id:  2016020292.json
# printing game : Game 2016020292 on 2016-11-23 between (29, 'CBJ', 0) and (20, 'CGY', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020293
# using cached data for game id:  2016020293.json
# using cached data for game id:  2016020293.json
# printing game : Game 2016020293 on 2016-11-23 between (30, 'MIN', 3) and (52, 'WPG', 1)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020294
# using cached data for game id:  2016020294.json
# using cached data for game id:  2016020294.json
# printing game : Game 2016020294 on 2016-11-23 between (14, 'TBL', 4) and (4, 'PHI', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020295
# using cached data for game id:  2016020295.json
# using cached data for game id:  2016020295.json
# printing game : Game 2016020295 on 2016-11-23 between (18, 'NSH', 5) and (25, 'DAL', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020296
# using cached data for game id:  2016020296.json
# using cached data for game id:  2016020296.json
# printing game : Game 2016020296 on 2016-11-23 between (21, 'COL', 3) and (22, 'EDM', 6)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020297
# using cached data for game id:  2016020297.json
# using cached data for game id:  2016020297.json
# printing game : Game 2016020297 on 2016-11-23 between (53, 'ARI', 1) and (23, 'VAN', 4)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020298
# using cached data for game id:  2016020298.json
# using cached data for game id:  2016020298.json
# printing game : Game 2016020298 on 2016-11-23 between (26, 'LAK', 4) and (2, 'NYI', 2)
# rebound
# Using cached data for game id:  2016020299
# using cached data for game id:  2016020299.json
# using cached data for game id:  2016020299.json
# printing game : Game 2016020299 on 2016-11-23 between (28, 'SJS', 2) and (16, 'CHI', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020300
# using cached data for game id:  2016020300.json
# using cached data for game id:  2016020300.json
# printing game : Game 2016020300 on 2016-11-24 between (8, 'MTL', 2) and (12, 'CAR', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020301
# using cached data for game id:  2016020301.json
# using cached data for game id:  2016020301.json
# printing game : Game 2016020301 on 2016-11-24 between (9, 'OTT', 3) and (6, 'BOS', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020302
# using cached data for game id:  2016020302.json
# using cached data for game id:  2016020302.json
# printing game : Game 2016020302 on 2016-11-25 between (4, 'PHI', 2) and (3, 'NYR', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020303
# using cached data for game id:  2016020303.json
# using cached data for game id:  2016020303.json
# printing game : Game 2016020303 on 2016-11-25 between (30, 'MIN', 6) and (5, 'PIT', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020304
# using cached data for game id:  2016020304.json
# using cached data for game id:  2016020304.json
# printing game : Game 2016020304 on 2016-11-25 between (24, 'ANA', 2) and (16, 'CHI', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020305
# using cached data for game id:  2016020305.json
# using cached data for game id:  2016020305.json
# printing game : Game 2016020305 on 2016-11-25 between (28, 'SJS', 3) and (2, 'NYI', 2)
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020306
# using cached data for game id:  2016020306.json
# using cached data for game id:  2016020306.json
# printing game : Game 2016020306 on 2016-11-25 between (15, 'WSH', 3) and (7, 'BUF', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020307
# using cached data for game id:  2016020307.json
# using cached data for game id:  2016020307.json
# printing game : Game 2016020307 on 2016-11-25 between (18, 'NSH', 5) and (52, 'WPG', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020308
# using cached data for game id:  2016020308.json
# using cached data for game id:  2016020308.json
# printing game : Game 2016020308 on 2016-11-25 between (6, 'BOS', 1) and (20, 'CGY', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020309
# using cached data for game id:  2016020309.json
# using cached data for game id:  2016020309.json
# printing game : Game 2016020309 on 2016-11-25 between (14, 'TBL', 3) and (29, 'CBJ', 5)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020310
# using cached data for game id:  2016020310.json
# using cached data for game id:  2016020310.json
# printing game : Game 2016020310 on 2016-11-25 between (1, 'NJD', 4) and (17, 'DET', 5)
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020311
# using cached data for game id:  2016020311.json
# using cached data for game id:  2016020311.json
# printing game : Game 2016020311 on 2016-11-25 between (25, 'DAL', 2) and (23, 'VAN', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020312
# using cached data for game id:  2016020312.json
# using cached data for game id:  2016020312.json
# printing game : Game 2016020312 on 2016-11-25 between (53, 'ARI', 3) and (22, 'EDM', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020313
# using cached data for game id:  2016020313.json
# using cached data for game id:  2016020313.json
# printing game : Game 2016020313 on 2016-11-26 between (10, 'TOR', 4) and (15, 'WSH', 2)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020314
# using cached data for game id:  2016020314.json
# using cached data for game id:  2016020314.json
# printing game : Game 2016020314 on 2016-11-26 between (9, 'OTT', 2) and (12, 'CAR', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020315
# using cached data for game id:  2016020315.json
# using cached data for game id:  2016020315.json
# printing game : Game 2016020315 on 2016-11-26 between (17, 'DET', 1) and (8, 'MTL', 2)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020316
# using cached data for game id:  2016020316.json
# using cached data for game id:  2016020316.json
# printing game : Game 2016020316 on 2016-11-26 between (13, 'FLA', 2) and (29, 'CBJ', 1)
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020317
# using cached data for game id:  2016020317.json
# using cached data for game id:  2016020317.json
# printing game : Game 2016020317 on 2016-11-26 between (5, 'PIT', 4) and (1, 'NJD', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020318
# using cached data for game id:  2016020318.json
# using cached data for game id:  2016020318.json
# printing game : Game 2016020318 on 2016-11-26 between (19, 'STL', 4) and (30, 'MIN', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020319
# using cached data for game id:  2016020319.json
# using cached data for game id:  2016020319.json
# printing game : Game 2016020319 on 2016-11-26 between (21, 'COL', 2) and (23, 'VAN', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020320
# using cached data for game id:  2016020320.json
# using cached data for game id:  2016020320.json
# printing game : Game 2016020320 on 2016-11-26 between (26, 'LAK', 2) and (16, 'CHI', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020321
# using cached data for game id:  2016020321.json
# using cached data for game id:  2016020321.json
# printing game : Game 2016020321 on 2016-11-26 between (28, 'SJS', 2) and (24, 'ANA', 3)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020322
# using cached data for game id:  2016020322.json
# using cached data for game id:  2016020322.json
# printing game : Game 2016020322 on 2016-11-27 between (6, 'BOS', 4) and (14, 'TBL', 1)
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# rebound
# Using cached data for game id:  2016020323
# using cached data for game id:  2016020323.json
# using cached data for game id:  2016020323.json
# printing game : Game 2016020323 on 2016-11-27 between (22, 'EDM', 1) and (53, 'ARI', 2)
# rebound
# rebound
# rebound
# rebound
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pp2.get_games_df(list(range(2016, 2020)))
#       2 df
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\preprocess_II.py:258, in PreprocessII.get_games_df(seasons, reset_df)
#     256     games = regular_season_game_id_generator(season)
#     257     for id in games:
# --> 258         data = PreprocessII(id)
#     259         data.to_dataframe()
#     260 return PreprocessII.games_df
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\preprocess_II.py:204, in PreprocessII.__init__(self, game_id)
#     202 self.game_data = []
#     203 for event in event_list:
# --> 204     row : Row = Row(event, game)
#     205     if row.home_team_side == 'central':
#     206         if period_homeSide.get(row.period_number) is None:
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\preprocess_II.py:50, in Row.__init__(self, shot, game)
#      48 self.speed = None
#      49 self.change_in_shot_angle = None
# ---> 50 self.set_home_team_side(shot.approximate_homeTeamSide(game))
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\preprocess_II.py:66, in Row.set_home_team_side(self, side)
#      64 self.compute_distance_from_net()
#      65 self.compute_angle_from_net()
# ---> 66 self.compute_angle_from_last_event()
#      67 self.compute_change_in_shot_angle()
#      68 self.compute_speed()
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\preprocess_II.py:112, in Row.compute_angle_from_last_event(self)
#     110     print("game_id", self.game_id)
#     111     print("event_id", self.event_id)
# --> 112 angle_radian = math.acos(cos_angle)
#     113 angle = math.degrees(angle_radian)
#     114 self.change_in_shot_angle = angle
#
# ValueError: math domain error

# %%
df[df["rebound"] == True]
# Out:
# Empty DataFrame
# Columns: [game_id, home_team_id, away_team_id, event_id, owner_team_id, event_type, shot_type, time_period, period_number, zone_code, x_coord, y_coord, flagged, last_event_type, last_event_xCoord, last_event_yCoord, time_passed_since_last_event, distance_from_last_event, rebound, distance_from_net, angle_from_net, speed, change_in_shot_angle, home_team_side]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.to_csv('../ift6758/data/feature_eng_2.csv', index=False)

# %%
cleaned_df = fe2(df)
cleaned_df.clean_df()
# Out:
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:133: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].mean(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:133: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].mean(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:133: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].mean(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
# c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:133: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[column].fillna(self.df[column].mean(), inplace=True)
# Error on column : change_in_shot_angle
#  row : 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 305809    None
# 305810    None
# 305811    None
# 305812    None
# 305813    None
# Name: change_in_shot_angle, Length: 305814, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 cleaned_df = fe2(df)
# ----> 2 cleaned_df.clean_df()
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:145, in FeatureEngineeringII.clean_df(self, remove_irrelevant)
#     142 def clean_df(self, remove_irrelevant=True):
#     143     """clean the dataframe by removing irrelevant columns, adding labels, numerising the columns and aligning the coordinates
#     144     """
# --> 145     self.replace_na()
#     146     self.add_labels()
#     147     self.numerise_zoneCode(one_hot_encode=False)
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:140, in FeatureEngineeringII.replace_na(self)
#     138 print(f"Error on column : {column}")
#     139 print(f" row : {self.df[column]}")
# --> 140 raise e
#
# File c:\users\dre\documents\agrosante_udem\cours\data_science\nhl project\ift-6758-project\ift6758\features\feature_engineering_II.py:136, in FeatureEngineeringII.replace_na(self)
#     134 else:
#     135     try:
# --> 136         self.df[column].fillna(self.df[column].value_counts().idxmax(), inplace=True)
#     137     except ValueError as e:
#     138         print(f"Error on column : {column}")
#
# File c:\Users\dre\miniconda3\envs\ift-6758-lab-venv\Lib\site-packages\pandas\core\series.py:2761, in Series.idxmax(self, axis, skipna, *args, **kwargs)
#    2756 with warnings.catch_warnings():
#    2757     # TODO(3.0): this catching/filtering can be removed
#    2758     # ignore warning produced by argmax since we will issue a different
#    2759     #  warning for argmax
#    2760     warnings.simplefilter("ignore")
# -> 2761     i = self.argmax(axis, skipna, *args, **kwargs)
#    2763 if i == -1:
#    2764     # GH#43587 give correct NA value for Index.
#    2765     warnings.warn(
#    2766         f"The behavior of {type(self).__name__}.idxmax with all-NA "
#    2767         "values, or any-NA and skipna=False, is deprecated. In a future "
#    (...)
#    2770         stacklevel=find_stack_level(),
#    2771     )
#
# File c:\Users\dre\miniconda3\envs\ift-6758-lab-venv\Lib\site-packages\pandas\core\base.py:751, in IndexOpsMixin.argmax(self, axis, skipna, *args, **kwargs)
#     749         return delegate.argmax()
#     750 else:
# --> 751     result = nanops.nanargmax(delegate, skipna=skipna)
#     752     if result == -1:
#     753         warnings.warn(
#     754             f"The behavior of {type(self).__name__}.argmax/argmin "
#     755             "with skipna=False and NAs, or with all-NAs is deprecated. "
#    (...)
#     758             stacklevel=find_stack_level(),
#     759         )
#
# File c:\Users\dre\miniconda3\envs\ift-6758-lab-venv\Lib\site-packages\pandas\core\nanops.py:1148, in nanargmax(values, axis, skipna, mask)
#    1116 """
#    1117 Parameters
#    1118 ----------
#    (...)
#    1145 array([2, 2, 1, 1])
#    1146 """
#    1147 values, mask = _get_values(values, True, fill_value_typ="-inf", mask=mask)
# -> 1148 result = values.argmax(axis)
#    1149 # error: Argument 1 to "_maybe_arg_null_out" has incompatible type "Any |
#    1150 # signedinteger[Any]"; expected "ndarray[Any, Any]"
#    1151 result = _maybe_arg_null_out(result, axis, mask, skipna)  # type: ignore[arg-type]
#
# ValueError: attempt to get argmax of an empty sequence

# %%
train, test = cleaned_df.split_train_test()

# %%
train

# %%
test
