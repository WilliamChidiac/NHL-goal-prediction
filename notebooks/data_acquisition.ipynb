# %%
from ift6758.data import *

# %%
retrieve_game_data(2017020001)
# Out:
# using cached data
# {'id': 2017020001,
#  'season': 20172018,
#  'gameType': 2,
#  'limitedScoring': False,
#  'gameDate': '2017-10-04',
#  'venue': {'default': 'Bell MTS Place'},
#  'venueLocation': {'default': 'Winnipeg'},
#  'startTimeUTC': '2017-10-04T23:00:00Z',
#  'easternUTCOffset': '-04:00',
#  'venueUTCOffset': '-05:00',
#  'tvBroadcasts': [{'id': 282,
#    'market': 'N',
#    'countryCode': 'CA',
#    'network': 'SN',
#    'sequenceNumber': 101},
#   {'id': 281,
#    'market': 'N',
#    'countryCode': 'CA',
#    'network': 'TVAS',
#    'sequenceNumber': 109}],
#  'gameState': 'OFF',
#  'gameScheduleState': 'OK',
#  'periodDescriptor': {'number': 3,
#   'periodType': 'REG',
#   'maxRegulationPeriods': 3},
#  'awayTeam': {'id': 10,
#   'name': {'default': 'Maple Leafs'},
#   'abbrev': 'TOR',
#   'score': 7,
#   'sog': 31,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/TOR_light.svg',
#   'placeName': {'default': 'Toronto'},
# ...

# %%
# 2017 regular season
year = "2019"
for game_number in range(1, int(game_number_per_year[year]) + 1):
    game_id = f"{year}{REGULAR_SEASON}{game_number:04d}"
    retrieve_game_data(game_id)
# Out:
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# using cached data
# ...
